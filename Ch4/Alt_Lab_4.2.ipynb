# %% [markdown]
# # Alt Lab 4.2 - Exploring Data with Filters and Descriptive Statistics

# %% [markdown]
# ## 1. Read the dataset into a pandas dataframe and visually explore it by limiting decimal precision to 2 and the displayed number of columns to 20.

# %% [markdown]
# ## 2. Filter the data for the companies ranked 66 to 120 and the "rnd_22", "mcap_22", and "capex_22" columns.

# %% [markdown]
# ## 3. Display descriptive statistics for the filtered data.

# %% [markdown]
# ## 4.  Calculate and display the coefficient of variation for the numerical columns in the filtered dataset.
