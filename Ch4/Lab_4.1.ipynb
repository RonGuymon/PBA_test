# %% [markdown]
# # Lab 4.1 - Exploring Dataframe Characteristics

# %% [markdown]
# ## 1. Read the dataset into a Pandas dataframe and visually explore it

# %% [markdown]
# ## 2. Visually explore a sample of the data

# %% [markdown]
# ## 3. Display individual elements shown in the summary information
