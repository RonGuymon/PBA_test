# %% [markdown]
# # Alt Lab 4.3 - Exploring Data with Visualizations - Solution

# %% [markdown]
# ## 1. Read the dataset into a pandas dataframe, filter it for companies ranked 66 to 120 and the columns you need for the remainder of the lab, and visually explore it.

# %% [markdown]
# ## 2. Create a bar chart to explore the number of observations from each industry. Make two charts, one for "icb3_short" and one for "icb3_name".

# %% [markdown]
# ## 3. Explore the distribution of market capitalization with box and whisker plots. Make plots for both the "icb3_short" and "icb3_name" categorizations.

# %% [markdown]
# ## 4. Explore the relationship between market capitalization and R&D expenditures with a scatter plot.
