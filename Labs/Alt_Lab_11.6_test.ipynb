# %% [markdown]
# # Alt Lab 11.6 Test
#
# Use the Alt_Lab_11.6_Data.csv file and complete the same analysis tasks, including the addition of insights.
#
# Use the Alt_Lab_11.6_Data.csv file, which can be loaded from this URL: https://raw.githubusercontent.com/RonGuymon/PBA_test/refs/heads/main/Labs/Alt_Lab_11.6_Data.csv
